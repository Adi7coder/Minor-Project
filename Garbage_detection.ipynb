# %% [markdown]
# <a href="https://colab.research.google.com/github/Adi7coder/Minor-Project/blob/segmentation/Garbage_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 37.4 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="HcWk84SEFo4kkBzvySj1")
project = rf.workspace("mini-project-zheci").project("garbage-segmentation-jr0aj")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")
model.train(data="/content/Garbage-Segmentation-1/data.yaml", epochs=50, imgsz=640)
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.9.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
from ultralytics import YOLO

model = YOLO("/content/runs/detect/train5/weights/best.pt")
metrics=model.val()
metrics
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.9.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# Model summary (fused): 73 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 397.7±73.0 MB/s, size: 87.6 KB)
# val: Scanning /content/Garbage-Segmentation-1/valid/labels.cache... 13 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 13/13 599.2Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.9s/it 4.9s
#                    all         13         22      0.829      0.455      0.479      0.325
# Speed: 56.6ms preprocess, 303.0ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to /content/runs/detect/val
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x785bec895e50>
# ...

# %%
from matplotlib import pyplot as plt

results = model.predict("/content/Garbage-Segmentation-1/test/images")

for r in results[:3]:
    plt.imshow(r.plot())
    plt.axis('off')
    plt.show()
# Out:
# image 1/10 /content/Garbage-Segmentation-1/test/images/1000034285_jpg.rf.b5c9b3a8d51502dc1668804d58aa3452.jpg: 640x640 1 garbage, 339.3ms
# image 2/10 /content/Garbage-Segmentation-1/test/images/1000034287_jpg.rf.e5c202921e37559c0c10cc23fec5b951.jpg: 640x640 1 garbage, 340.6ms
# image 3/10 /content/Garbage-Segmentation-1/test/images/1000034291_jpg.rf.4164f239d8dfaf80f473e9ce82c1c8cf.jpg: 640x640 3 garbages, 320.8ms
# image 4/10 /content/Garbage-Segmentation-1/test/images/images-5-_jpeg.rf.0eb2b4c258ea5be8f9a4bbe0ca65b6dd.jpg: 640x640 1 garbage, 254.2ms
# image 5/10 /content/Garbage-Segmentation-1/test/images/suggested-ASUWVenHKKHHRa0eKjYT_jpg.rf.e15efa1ae58c2a5b9ffe78c3cb2af948.jpg: 640x640 1 garbage, 225.8ms
# image 6/10 /content/Garbage-Segmentation-1/test/images/suggested-TELpBQIpGIdrP8G91FjP_jpg.rf.d1a0177e6819e567b8774d023b097dfe.jpg: 640x640 1 garbage, 205.7ms
# ...
